# %%
#Import required libraries for data loading, cleaning and pre processing.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# 1   88.7 bhp    5.0  8.61 Lakh   4.50
# 2  88.76 bhp    7.0        NaN   6.00
# 3  140.8 bhp    5.0        NaN  17.74
# 4   63.1 bhp    5.0        NaN   3.50

# %% [markdown]
# **The dataset consists of 5847 rows and 14 columns**

# %%
#Descriptive Statistics
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5847 entries, 0 to 5846
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5847 non-null   int64
#  1   Name               5847 non-null   object
#  2   Location           5847 non-null   object
#  3   Year               5847 non-null   int64
#  4   Kilometers_Driven  5847 non-null   int64
#  5   Fuel_Type          5847 non-null   object
#  6   Transmission       5847 non-null   object
#  7   Owner_Type         5847 non-null   object
#  8   Mileage            5845 non-null   object
#  9   Engine             5811 non-null   object
#  10  Power              5811 non-null   object
#  11  Seats              5809 non-null   float64
#  12  New_Price          815 non-null    object
#  13  Price              5847 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 639.6+ KB
# None
#         Unnamed: 0         Year  Kilometers_Driven        Seats        Price
# count  5847.000000  5847.000000       5.847000e+03  5809.000000  5847.000000
# mean   3013.181461  2013.448435       5.841013e+04     5.286452     9.653742
# std    1736.398890     3.194949       9.237971e+04     0.806668    11.275966
# min       1.000000  1998.000000       1.710000e+02     2.000000     0.440000
# 25%    1509.500000  2012.000000       3.346750e+04     5.000000     3.550000
# 50%    3015.000000  2014.000000       5.257600e+04     5.000000     5.750000
# 75%    4517.500000  2016.000000       7.249050e+04     5.000000    10.250000
# max    6018.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %% [markdown]
# ## **a) Handling Missing Values**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %% [markdown]
# 1. Mileage, Engine, Power, Seats: These columns have only a small portion of missing values relative to the dataset size. Mean imputation has been done here since they are numerical features
#
# 2. New_Price: Filling missing values with 0

# %%
# Extract numeric values and convert the columns
df['Mileage'] = df['Mileage'].str.extract(r'(\d+\.\d+|\d+)').astype(float)  # Remove non-numeric parts and convert to float
df['Engine'] = df['Engine'].str.extract(r'(\d+)').astype(float)
df['Power'] = df['Power'].str.extract(r'(\d+\.\d+|\d+)').astype(float)

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Impute missing values using the mean for Mileage, Engine, Power, Seats
df['Mileage'].fillna(df['Mileage'].mean(), inplace=True)
df['Engine'].fillna(df['Engine'].mean(), inplace=True)
df['Power'].fillna(df['Power'].mean(), inplace=True)
df['Seats'].fillna(df['Seats'].mean(), inplace=True)

# %%
# Fill missing values in 'New_Price' with 0 (as a placeholder)
df['New_Price'].fillna(0, inplace=True)

# Function to clean the 'New_Price' column
def clean_new_price(price):
    if isinstance(price, str):  # Check if the value is a string
        if 'Cr' in price:
            return float(price.replace(' Cr', '')) * 100
        elif 'Lakh' in price:
            return float(price.replace(' Lakh', ''))
    return price  # Return as is if it's already numeric or NaN

# Apply the function and convert to float
df['New_Price'] = df['New_Price'].apply(clean_new_price).astype(float)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# dtype: int64

# %% [markdown]
# **We can see that there are no missing values after being imputed.**

# %% [markdown]
# ## **Step b: The units have already been removed while extracting the numeric columns**

# %% [markdown]
# ## **C) Label encoding categorical features**
#
# 1. Fuel_Type and Transmission were converted into numerical Label encoded columns.

# %%
# c) Label encoding for Fuel_Type and Transmission
df['Fuel_Type'] = df['Fuel_Type'].astype('category').cat.codes
df['Transmission'] = df['Transmission'].astype('category').cat.codes

# %% [markdown]
# ## **d) Creating a New Feature:**
# A new column Car_Age was added, representing the car's age (2024 - Year).

# %%
# d) Create new feature 'Mileage_per_CC'
df['Mileage_per_CC'] = df['Mileage'] / df['Engine']
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             1      First    19.67  1582.0
# 1              46000          2             1      First    13.00  1199.0
# 2              87000          0             1      First    20.77  1248.0
# 3              40670          0             0     Second    15.20  1968.0
# 4              86999          0             1      First    23.08  1461.0
#
#     Power  Seats  New_Price  Price  Mileage_per_CC
# 0  126.20    5.0       0.00  12.50        0.012434
# 1   88.70    5.0       8.61   4.50        0.010842
# 2   88.76    7.0       0.00   6.00        0.016643
# 3  140.80    5.0       0.00  17.74        0.007724
# 4   63.10    5.0       0.00   3.50        0.015797

# %% [markdown]
# ## **e) SQL-Like Operations:**

# %%
# Select
selected_df = df[['Name', 'Location', 'Price', 'Mileage', 'Power', 'Mileage_per_CC']]
selected_df.head()
# Out:
#                                Name    Location  Price  Mileage   Power  \
# 0  Hyundai Creta 1.6 CRDi SX Option        Pune  12.50    19.67  126.20
# 1                      Honda Jazz V     Chennai   4.50    13.00   88.70
# 2                 Maruti Ertiga VDI     Chennai   6.00    20.77   88.76
# 3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  17.74    15.20  140.80
# 4            Nissan Micra Diesel XV      Jaipur   3.50    23.08   63.10
#
#    Mileage_per_CC
# 0        0.012434
# 1        0.010842
# 2        0.016643
# 3        0.007724
# 4        0.015797

# %%
# Filter rows where Mileage is greater than 15
filtered_df = selected_df[selected_df['Mileage'] > 15]
filtered_df.head()
# Out:
#                                   Name    Location  Price  Mileage   Power  \
# 0     Hyundai Creta 1.6 CRDi SX Option        Pune  12.50    19.67  126.20
# 2                    Maruti Ertiga VDI     Chennai   6.00    20.77   88.76
# 3      Audi A4 New 2.0 TDI Multitronic  Coimbatore  17.74    15.20  140.80
# 4               Nissan Micra Diesel XV      Jaipur   3.50    23.08   63.10
# 6  Volkswagen Vento Diesel Comfortline        Pune   5.20    20.54  103.60
#
#    Mileage_per_CC
# 0        0.012434
# 2        0.016643
# 3        0.007724
# 4        0.015797
# 6        0.012854

# %%
# Rename column
renamed_df = filtered_df.rename(columns={'Power': 'Horsepower'})
renamed_df.head()
# Out:
#                                   Name    Location  Price  Mileage  \
# 0     Hyundai Creta 1.6 CRDi SX Option        Pune  12.50    19.67
# 2                    Maruti Ertiga VDI     Chennai   6.00    20.77
# 3      Audi A4 New 2.0 TDI Multitronic  Coimbatore  17.74    15.20
# 4               Nissan Micra Diesel XV      Jaipur   3.50    23.08
# 6  Volkswagen Vento Diesel Comfortline        Pune   5.20    20.54
#
#    Horsepower  Mileage_per_CC
# 0      126.20        0.012434
# 2       88.76        0.016643
# 3      140.80        0.007724
# 4       63.10        0.015797
# 6      103.60        0.012854

# %%
# Arrange data by Mileage in descending order
arranged_df = renamed_df.sort_values(by='Mileage', ascending=False)
arranged_df.head()
# Out:
#                            Name   Location  Price  Mileage  Horsepower  \
# 3472  Maruti Dzire AMT ZDI Plus    Chennai   8.90     28.4       73.75
# 1877      Maruti Dzire ZDI Plus     Jaipur   8.20     28.4       73.75
# 1471  Maruti Dzire AMT ZDI Plus  Hyderabad   9.15     28.4       73.75
# 2437           Maruti Swift VDI       Pune   6.00     28.4       74.00
# 2361           Maruti Dzire VDI  Hyderabad   4.00     28.4       73.75
#
#       Mileage_per_CC
# 3472        0.022756
# 1877        0.022756
# 1471        0.022756
# 2437        0.022756
# 2361        0.022756

# %%
# Summarize by Location and calculate the average Power
summary_df = arranged_df.groupby('Location').agg({'Horsepower': 'mean'}).reset_index()
summary_df.head()
# Out:
#      Location  Horsepower
# 0   Ahmedabad  101.203506
# 1   Bangalore  110.233503
# 2     Chennai   97.864465
# 3  Coimbatore  106.029738
# 4       Delhi  101.568200
